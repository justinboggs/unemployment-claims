# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.dates as dates

# %%
unemploy_data = pd.read_csv("data/ICNSA.csv")

# %%
unemploy_data.head()
# Out:
#         DATE   ICNSA
# 0   1/7/1967  346000
# 1  1/14/1967  334000
# 2  1/21/1967  277000
# 3  1/28/1967  252000
# 4   2/4/1967  274000

# %%
initial_claims = unemploy_data.rename(columns={'DATE':'Date', 'ICNSA':'Claims'})
initial_claims.head()
# Out:
#         Date  Claims
# 0   1/7/1967  346000
# 1  1/14/1967  334000
# 2  1/21/1967  277000
# 3  1/28/1967  252000
# 4   2/4/1967  274000

# %%
initial_claims['Year'] = pd.DatetimeIndex(initial_claims['Date']).year
initial_claims.head()
# Out:
#         Date  Claims  Year
# 0   1/7/1967  346000  1967
# 1  1/14/1967  334000  1967
# 2  1/21/1967  277000  1967
# 3  1/28/1967  252000  1967
# 4   2/4/1967  274000  1967

# %%
x_axis = initial_claims['Date']
y_axis = initial_claims['Claims']
year = initial_claims['Year']

# %%
fig = plt.figure(figsize=(40,15))
ax = fig.add_subplot()
chart = plt.plot(initial_claims['Date'], initial_claims['Claims'], color='blue', alpha=0.9)
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.savefig('output/weekly_claims.png')
plt.show()
