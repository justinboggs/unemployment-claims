# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.dates as dates

# %%
data = pd.read_csv('data/UNRATE.csv')

# %%
data.tail()
# Out:
#            DATE  UNRATE
# 869  2020-06-01    11.1
# 870  2020-07-01    10.2
# 871  2020-08-01     8.4
# 872  2020-09-01     7.9
# 873  2020-10-01     6.9

# %%
unemploy_rate = data.rename(columns={'DATE': 'Date', 'UNRATE': 'Rate'})
unemploy_rate.tail()
# Out:
#            Date  Rate
# 869  2020-06-01  11.1
# 870  2020-07-01  10.2
# 871  2020-08-01   8.4
# 872  2020-09-01   7.9
# 873  2020-10-01   6.9

# %%
x_axis = unemploy_rate['Date']
y_axis = unemploy_rate['Rate']

# %%
fig = plt.figure(figsize=(40,15))
ax = fig.add_subplot()
chart = plt.plot(unemploy_rate['Date'], unemploy_rate['Rate'], color='blue', alpha=0.9)
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.xticks(rotation=90)
plt.savefig('output/monthly_rate.png')
plt.show()
